# %%
import json
import pymongo
import tweepy
import webbrowser

with open('api_key.txt', 'r') as f:
    consumer_key =  f.read()
f.closed

with open('api_secret.txt', 'r') as f:
    consumer_secret = f.read()
f.closed

with open('access_token.txt', 'r') as f:
    access_key = f.read()
f.closed

with open('access_token_secret.txt', 'r') as f:
     access_secret = f.read()
f.closed

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

USER_NAME = "subbar77"
user = api.get_user(id=USER_NAME)
print (user)
# Out:
# User(_api=<tweepy.api.API object at 0x0000019510F1A048>, _json={'id': 875478667, 'id_str': '875478667', 'name': 'k venkata subbareddy', 'screen_name': 'subbar77', 'location': 'Pune, India', 'profile_location': {'id': '5c0761bdffa0cb64', 'url': 'https://api.twitter.com/1.1/geo/id/5c0761bdffa0cb64.json', 'place_type': 'unknown', 'name': 'Pune, India', 'full_name': 'Pune, India', 'country_code': '', 'country': '', 'contained_within': [], 'bounding_box': None, 'attributes': {}}, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 23, 'friends_count': 95, 'listed_count': 0, 'created_at': 'Fri Oct 12 11:53:02 +0000 2012', 'favourites_count': 5, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 7, 'lang': None, 'status': {'created_at': 'Tue Oct 01 21:14:35 +0000 2019', 'id': 1179142587833372672, 'id_str': '1179142587833372672', 'text': 'What a performance even at the age of 64 yrs.... Waiting eagerly😍 https://t.co/CCWd7VkhVh', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CCWd7VkhVh', 'expanded_url': 'https://twitter.com/AsliShiva/status/1179025682678140929', 'display_url': 'twitter.com/AsliShiva/stat…', 'indices': [66, 89]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1179025682678140929, 'quoted_status_id_str': '1179025682678140929', 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/560850286932029440/1nyVkKoE_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/560850286932029440/1nyVkKoE_normal.jpeg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [], 'suspended': False, 'needs_phone_verification': False}, id=875478667, id_str='875478667', name='k venkata subbareddy', screen_name='subbar77', location='Pune, India', profile_location={'id': '5c0761bdffa0cb64', 'url': 'https://api.twitter.com/1.1/geo/id/5c0761bdffa0cb64.json', 'place_type': 'unknown', 'name': 'Pune, India', 'full_name': 'Pune, India', 'country_code': '', 'country': '', 'contained_within': [], 'bounding_box': None, 'attributes': {}}, description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=23, friends_count=95, listed_count=0, created_at=datetime.datetime(2012, 10, 12, 11, 53, 2), favourites_count=5, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=7, lang=None, status=Status(_api=<tweepy.api.API object at 0x0000019510F1A048>, _json={'created_at': 'Tue Oct 01 21:14:35 +0000 2019', 'id': 1179142587833372672, 'id_str': '1179142587833372672', 'text': 'What a performance even at the age of 64 yrs.... Waiting eagerly😍 https://t.co/CCWd7VkhVh', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CCWd7VkhVh', 'expanded ...

# %%
user.screen_name
# Out:
# 'subbar77'

# %%
timeline = api.user_timeline(id='POTUS',count=5)
#Retrieve a Status object...

for status in timeline:
    print (status.text+ "\n")
# Out:
# Tune in as I deliver remarks on the August jobs report. https://t.co/gdgovVvNDs
#
# Over the last week, I’ve been in constant communication with FEMA as we respond to Ida. We’re working around the cl… https://t.co/0qIWab5Hyt
#
# To all those still in harm’s way or struggling to deal with the aftermath of these storms and fires — God bless you… https://t.co/2e07FA3cdq
#
# Let’s keep this progress going and defeat this virus.
#
# Get vaccinated: https://t.co/jlrmakxHWm https://t.co/eTmoQRPXRY
#
# The past few days of Hurricane Ida, wildfires in the West, and unprecedented flash floods in New York and New Jerse… https://t.co/Ingoz8q1M2

# %%
#We can access the full JSON
user._json
# Out:
# {'id': 875478667,
#  'id_str': '875478667',
#  'name': 'k venkata subbareddy',
#  'screen_name': 'subbar77',
#  'location': 'Pune, India',
#  'profile_location': {'id': '5c0761bdffa0cb64',
#   'url': 'https://api.twitter.com/1.1/geo/id/5c0761bdffa0cb64.json',
#   'place_type': 'unknown',
#   'name': 'Pune, India',
#   'full_name': 'Pune, India',
#   'country_code': '',
#   'country': '',
#   'contained_within': [],
#   'bounding_box': None,
#   'attributes': {}},
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 23,
#  'friends_count': 95,
#  'listed_count': 0,
#  'created_at': 'Fri Oct 12 11:53:02 +0000 2012',
#  'favourites_count': 5,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 7,
#  'lang': None,
#  'status': {'created_at': 'Tue Oct 01 21:14:35 +0000 2019',
#   'id': 1179142587833372672,
#   'id_str': '1179142587833372672',
#   'text': 'What a performance even at the age of 64 yrs.... Waiting eagerly😍 https://t.co/CCWd7VkhVh',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/CCWd7VkhVh',
#      'expanded_url': 'https://twitter.com/AsliShiva/status/1179025682678140929',
#      'display_url': 'twitter.com/AsliShiva/stat…',
#      'indices': [66, 89]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1179025682678140929,
#   'quoted_status_id_str': '1179025682678140929',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/560850286932029440/1nyVkKoE_normal.jpeg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/560850286932029440/1nyVkKoE_normal.jpeg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'withheld_in_countries': [],
#  'suspended': False,
#  'needs_phone_verification': False}

# %%
juser = user._json
print (juser['created_at'])
img_url = juser['profile_image_url']
print (img_url)
# Out:
# Fri Oct 12 11:53:02 +0000 2012
# http://pbs.twimg.com/profile_images/560850286932029440/1nyVkKoE_normal.jpeg

# %%
import urllib
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt

im = Image.open(urllib.request.urlopen(img_url))
plt.title(juser['screen_name'],size=16)
plt.imshow(im)

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "xbox lang:en"
start_time = "2021-03-01T00:00:00.000Z"
end_time = "2021-03-31T00:00:00.000Z"
max_results = 15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-6c9129907121> in <module>
#       1 #Inputs for the request
# ----> 2 bearer_token = auth()
#       3 headers = create_headers(bearer_token)
#       4 keyword = "xbox lang:en"
#       5 start_time = "2021-03-01T00:00:00.000Z"
#
# TypeError: 'OAuthHandler' object is not callable

# %%
from tweepy import Stream,StreamListener

class listener(StreamListener): #listener is something that listens and waits for some commands i.e. some input from devices, here it is waiting for a tweet
    
    def __init__(self): #when listener is initialised for the first time, we use __init__
        super(StreamListener, self).__init__()
        self.num_tweets = 0
    def on_data(self, data):
        #Beauty print data
        if self.num_tweets < 5:
            parsed = json.loads(data)
            print (json.dumps(parsed, indent=4, sort_keys=True))
            self.num_tweets += 1
            return True
        else:
            return False

    def on_error(self, status):
        print ("Error "+str(status))

# %%
twitterStream = Stream(auth, listener()) 
twitterStream.filter(track="Bahubali") #coordinates can be obtained from bounding box
print ("done")
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 03 17:24:57 +0000 2021",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1433843468384849922",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/T7JP5BlcPP"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 50325797,
#                 "id_str": "50325797",
#                 "indices": [
#                     0,
#                     10
#                 ],
#                 "name": "Chuck Todd",
#                 "screen_name": "chucktodd"
#             }
#         ]
#     },
#     "extended_tweet": {
#         "display_text_range": [
#             0,
#             276
#         ],
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": [
#                 {
#                     "id": 50325797,
#                     "id_str": "50325797",
#                     "indices": [
#                         0,
#                         10
#                     ],
#                     "name": "Chuck Todd",
#                     "screen_name": "chucktodd"
#                 }
#             ]
#         },
#         "full_text": "@chucktodd you want to talk about biden's poll numbers. Well thanks to you and the rest of the crazy media, you drove his poll numbers down with your constant bashing over afganastan. You and the rest of your media don't give a damn about Afghanistan and you never have. Shame"
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 1433843468384849922,
#     "id_str": "1433843468384849922",
#     "in_reply_to_screen_name": "chucktodd",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": 50325797,
#     "in_reply_to_user_id_str": "50325797",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "@chucktodd you want to talk about biden's poll numbers. Well thanks to you and the rest of the crazy media, you dro\u2026 https://t.co/T7JP5BlcPP",
#     "timestamp_ms": "1630689897043",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Mar 04 18:15:55 +0000 2021",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": null,
#         "favourites_count": 1,
#         "follow_request_sent": null,
#         "followers_count": 2,
#         "following": null,
#         "friends_count": 14,
#         "geo_enabled": false,
#         "id": 1367539252872019973,
#         "id_str": "1367539252872019973",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 0,
#         "location": null,
#         "name": "James Ford",
#         "notifications": null,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": "",
#         "profile_background_image_url_https": "",
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "JamesFo13109894",
#         "statuses_count": 371,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false,
#         "withheld_in_countries": []
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 03 17:24:57 +0000 2021",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 1323747268013527041,
#                 "id_str": "1323747268013527041",
#                 "indices": [
#                     3,
#                     18
#                 ],
#                 "name": "JDLM",
#                 "screen_name": "NicolasPichot6"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 1433843468309340160,
#     "id_str": "1433843468309340160",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "fr",
#     "place": null,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Sep 03 15:11:43 +0000 2021",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/1433809939043078146",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/c6qYvLmLXR"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "extended_tweet": {
#             "display_text_range": [
#                 0,
#                 278
#             ],
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             200,
#                             221
#                         ],
#                         "text": "MortApresVaccination"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "darik.news/en/a-41-year-o\u2026",
#                         "expanded_url": "https://darik.news/en/a-41-year-old-man-was-vaccinated-and-mysteriously-died-on-the-struma-highway.html",
#                         "indices": [
#                             255,
#                             278
#                         ],
#                         "url": "https://t.co/GJD323li7l"
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "id": 1243861395759935488,
#                         "id_str": "1243861395759935488",
#                         "indices": [
#                             231,
#                             240
#                         ],
#                         "name": "AnneDv_in21\ud83d\udcab",
#                         "screen_name": "ADv_in21"
#                     },
#                     {
#                         "id": 1281278365341757445,
#                         "id_str": "1281278365341757445",
#                         "indices": [
#                             241,
#                             253
#                         ],
#                         "name": "Complo Tisss Spare (V)",
#                         "screen_name": "ComploTisss"
#                     }
#                 ]
#             },
#             "full_text": "\ud83d\udd34MACEDOINE DU NORD - Un homme de 41 ans est mort myst\u00e9rieusement sur l'autoroute. Vaccin\u00e9 il y a qques jours en Hollande, son employeur l'avait laiss\u00e9 rentrer car il se sentait mal apr\u00e8s l'injection.\n#MortApresVaccination\n\ud83d\udce2 \u26a1\ufe0f\u26a1\ufe0f\u26a1\ufe0f\n@ADv_in21 @ComploTisss \nhttps://t.co/GJD323li7l"
#         },
#         "favorite_count": 35,
#         "favorited": false,
#         "filter_level": "low",
#         "geo": null,
#         "id": 1433809939043078146,
#         "id_str": "1433809939043078146",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "fr",
#         "place": null,
#         "possibly_sensitive": false,
#         "quote_count": 0,
#         "reply_count": 0,
#         "retweet_count": 28,
#         "retweeted": false,
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "text": "\ud83d\udd34MACEDOINE DU NORD - Un homme de 41 ans est mort myst\u00e9rieusement sur l'autoroute. Vaccin\u00e9 il y a qques jours en Hol\u2026 https://t.co/c6qYvLmLXR",
#         "truncated": true,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Tue Nov 03 22:02:18 +0000 2020",
#             "default_profile": true,
#             "default_profile_image": false,
#             "description": "https://gettr.com/user/jdlm_",
#             "favourites_count": 11589,
#             "follow_request_sent": null,
#             "followers_count": 7320,
#             "following": null,
#             "friends_count": 294,
#             "geo_enabled": false,
#             "id": 1323747268013527041,
#             "id_str": "1323747268013527041",
#             "is_translator": false,
#             "lang": null,
#             "listed_count": 57,
#             "location": null,
#             "name": "JDLM",
#             "notifications": null,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": "",
#             "profile_background_image_url_https": "",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1323747268013527041/1604984085",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1326025144452702208/fKkhEn-B_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1326025144452702208/fKkhEn-B_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "NicolasPichot6",
#             "statuses_count": 12330,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": null,
#             "utc_offset": null,
#             "verified": false,
#             "withheld_in_countries": []
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "RT @NicolasPichot6: \ud83d\udd34MACEDOINE DU NORD - Un homme de 41 ans est mort myst\u00e9rieusement sur l'autoroute. Vaccin\u00e9 il y a qques jours en Holland\u2026",
#     "timestamp_ms": "1630689897025",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Mon Feb 01 09:58:03 +0000 2010",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "J'aime pas les cons, les traitres, les hypocrites, les pourris....et les moutons !!!\n#Parler Isacora #Vk Isa RUBIO",
#         "favourites_count": 59489,
#         "follow_request_sent": null,
#         "followers_count": 1067,
#         "following": null,
#         "friends_count": 2550,
#         "geo_enabled": true,
#         "id": 110377908,
#         "id_str": "110377908",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 2,
#         "location": "FRANCE",
#         "name": "Isa de France",
#         "notifications": null,
#         "profile_background_color": "C3D1EB",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/110377908/1625488790",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1423335026591154183/ILgQsPaM_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1423335026591154183/ILgQsPaM_normal.jpg",
#         "profile_link_color": "89C9FA",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "E5507E",
#         "profile_text_color": "362720",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "LovephilC",
#         "statuses_count": 40471,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false,
#         "withheld_in_countries": []
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 03 17:24:57 +0000 2021",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 37686676,
#                 "id_str": "37686676",
#                 "indices": [
#                     3,
#                     19
#                 ],
#                 "name": "Ruddy Rodriguez",
#                 "screen_name": "RuddyRRodriguez"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 1433843468502245386,
#     "id_str": "1433843468502245386",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "es",
#     "place": null,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Thu Sep 02 16:15:59 +0000 2021",
#         "display_text_range": [
#             0,
#             140
#         ],
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/1433463726246617093",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/INZgMO4hV7"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "extended_tweet": {
#             "display_text_range": [
#                 0,
#                 123
#             ],
#             "entities": {
#                 "hashtags": [],
#                 "media": [
#                     {
#                         "display_url": "pic.twitter.com/TnTMuyrFPe",
#                         "expanded_url": "https://twitter.com/RuddyRRodriguez/status/1433463726246617093/photo/1",
#                         "id": 1433463723117666308,
#                         "id_str": "1433463723117666308",
#                         "indices": [
#                             124,
#                             147
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/E-SvqU7WYAQLHcG.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/E-SvqU7WYAQLHcG.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 832,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "medium": {
#                                 "h": 832,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "small": {
#                                 "h": 680,
#                                 "resize": "fit",
#                                 "w": 490
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "type": "photo",
#                         "url": "https://t.co/TnTMuyrFPe"
#                     },
#                     {
#                         "display_url": "pic.twitter.com/TnTMuyrFPe",
#                         "expanded_url": "https://twitter.com/RuddyRRodriguez/status/1433463726246617093/photo/1",
#                         "id": 1433463723126108161,
#                         "id_str": "1433463723126108161",
#                         "indices": [
#                             124,
#                             147
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/E-SvqU9XMAEJzIZ.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/E-SvqU9XMAEJzIZ.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 1200,
#                                 "resize": "fit",
#                                 "w": 904
#                             },
#                             "medium": {
#                                 "h": 1200,
#                                 "resize": "fit",
#                                 "w": 904
#                             },
#                             "small": {
#                                 "h": 680,
#                                 "resize": "fit",
#                                 "w": 512
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "type": "photo",
#                         "url": "https://t.co/TnTMuyrFPe"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": []
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "display_url": "pic.twitter.com/TnTMuyrFPe",
#                         "expanded_url": "https://twitter.com/RuddyRRodriguez/status/1433463726246617093/photo/1",
#                         "id": 1433463723117666308,
#                         "id_str": "1433463723117666308",
#                         "indices": [
#                             124,
#                             147
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/E-SvqU7WYAQLHcG.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/E-SvqU7WYAQLHcG.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 832,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "medium": {
#                                 "h": 832,
#                                 "resize": "fit",
#                                 "w": 600
#                             },
#                             "small": {
#                                 "h": 680,
#                                 "resize": "fit",
#                                 "w": 490
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "type": "photo",
#                         "url": "https://t.co/TnTMuyrFPe"
#                     },
#                     {
#                         "display_url": "pic.twitter.com/TnTMuyrFPe",
#                         "expanded_url": "https://twitter.com/RuddyRRodriguez/status/1433463726246617093/photo/1",
#                         "id": 1433463723126108161,
#                         "id_str": "1433463723126108161",
#                         "indices": [
#                             124,
#                             147
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/E-SvqU9XMAEJzIZ.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/E-SvqU9XMAEJzIZ.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 1200,
#                                 "resize": "fit",
#                                 "w": 904
#                             },
#                             "medium": {
#                                 "h": 1200,
#                                 "resize": "fit",
#                                 "w": 904
#                             },
#                             "small": {
#                                 "h": 680,
#                                 "resize": "fit",
#                                 "w": 512
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "type": "photo",
#                         "url": "https://t.co/TnTMuyrFPe"
#                     }
#                 ]
#             },
#             "full_text": "Recuerdo la primera vez que fui a Ecuador \ud83c\uddea\ud83c\udde8 le di la vuelta corriendo al estadio y aqu\u00ed apoyando en esa \u00e9poca al Barcelona https://t.co/TnTMuyrFPe"
#         },
#         "favorite_count": 7722,
#         "favorited": false,
#         "filter_level": "low",
#         "geo": null,
#         "id": 1433463726246617093,
#         "id_str": "1433463726246617093",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "es",
#         "place": null,
#         "possibly_sensitive": false,
#         "quote_count": 117,
#         "reply_count": 271,
#         "retweet_count": 1444,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "text": "Recuerdo la primera vez que fui a Ecuador \ud83c\uddea\ud83c\udde8 le di la vuelta corriendo al estadio y aqu\u00ed apoyando en esa \u00e9poca al B\u2026 https://t.co/INZgMO4hV7",
#         "truncated": true,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Mon May 04 15:46:12 +0000 2009",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Actriz.",
#             "favourites_count": 980,
#             "follow_request_sent": null,
#             "followers_count": 413904,
#             "following": null,
#             "friends_count": 480,
#             "geo_enabled": false,
#             "id": 37686676,
#             "id_str": "37686676",
#             "is_translator": false,
#             "lang": null,
#             "listed_count": 1083,
#             "location": "Florece y Prospera. ",
#             "name": "Ruddy Rodriguez",
#             "notifications": null,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/37686676/1466781340",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/483832354629107712/2hhwQGYa_normal.jpeg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/483832354629107712/2hhwQGYa_normal.jpeg",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "F2E9F2",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "RuddyRRodriguez",
#             "statuses_count": 5924,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "http://www.ruddyrodriguez.com",
#             "utc_offset": null,
#             "verified": false,
#             "withheld_in_countries": []
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "RT @RuddyRRodriguez: Recuerdo la primera vez que fui a Ecuador \ud83c\uddea\ud83c\udde8 le di la vuelta corriendo al estadio y aqu\u00ed apoyando en esa \u00e9poca al Barc\u2026",
#     "timestamp_ms": "1630689897071",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Jun 08 23:13:34 +0000 2010",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "La vida es una T\u00f3mbola...",
#         "favourites_count": 6423,
#         "follow_request_sent": null,
#         "followers_count": 486,
#         "following": null,
#         "friends_count": 777,
#         "geo_enabled": true,
#         "id": 153585493,
#         "id_str": "153585493",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 1,
#         "location": "Manta \u2734Ecuador ",
#         "name": "Cristhian Castro",
#         "notifications": null,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/153585493/1380594290",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/696973271321985024/fClrHwOr_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/696973271321985024/fClrHwOr_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "cristhiancm",
#         "statuses_count": 10139,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false,
#         "withheld_in_countries": []
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 03 17:24:57 +0000 2021",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 4769536303,
#                 "id_str": "4769536303",
#                 "indices": [
#                     3,
#                     15
#                 ],
#                 "name": "Tosca Austen",
#                 "screen_name": "ToscaAusten"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 1433843468514824193,
#     "id_str": "1433843468514824193",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Sep 03 14:08:47 +0000 2021",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/1433794103049965579",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/pX5V8BkItl"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "extended_tweet": {
#             "display_text_range": [
#                 0,
#                 280
#             ],
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": []
#             },
#             "full_text": "Jobs down. Half a million FEWER jobs created in August than expected.\nBiden policies pay monthly stipends\u2014some cases higher than people\u2019s wages, rent, transportation, housing, food, medical.\nCradle to grave type handouts initiated under covid w/o legislation.\n\nWhy bother to work?"
#         },
#         "favorite_count": 42,
#         "favorited": false,
#         "filter_level": "low",
#         "geo": null,
#         "id": 1433794103049965579,
#         "id_str": "1433794103049965579",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "quote_count": 1,
#         "reply_count": 7,
#         "retweet_count": 41,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "text": "Jobs down. Half a million FEWER jobs created in August than expected.\nBiden policies pay monthly stipends\u2014some case\u2026 https://t.co/pX5V8BkItl",
#         "truncated": true,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Sat Jan 16 17:33:26 +0000 2016",
#             "default_profile": true,
#             "default_profile_image": false,
#             "description": "Ghostwriter.Political Aficionado, Bonvivant \ud83c\udf43Ballet l\u2019Op\u00e9ra Paris \ud83c\udfb6Trilingual: English,French Italian\ud83c\uddfa\ud83c\uddf8\ud83c\uddee\ud83c\uddf9 Critical Thinker, Indy, Parler: ToscaAusten",
#             "favourites_count": 121942,
#             "follow_request_sent": null,
#             "followers_count": 32036,
#             "following": null,
#             "friends_count": 17858,
#             "geo_enabled": true,
#             "id": 4769536303,
#             "id_str": "4769536303",
#             "is_translator": false,
#             "lang": null,
#             "listed_count": 40,
#             "location": "DeBlasio Cuomo Refugee",
#             "name": "Tosca Austen",
#             "notifications": null,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": "",
#             "profile_background_image_url_https": "",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/4769536303/1610767418",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1298241226156769282/k_oDUmyf_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1298241226156769282/k_oDUmyf_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "ToscaAusten",
#             "statuses_count": 227192,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "http://GAB.com/ToscaAusten",
#             "utc_offset": null,
#             "verified": false,
#             "withheld_in_countries": []
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @ToscaAusten: Jobs down. Half a million FEWER jobs created in August than expected.\nBiden policies pay monthly stipends\u2014some cases highe\u2026",
#     "timestamp_ms": "1630689897074",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sat Dec 28 20:02:25 +0000 2019",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Conservative Texan \u201cThere\u2019s no normal life, there\u2019s just life.\u201d I Back the Blue. I Stand for the Flag. And, I stand for protecting our unborn babies.",
#         "favourites_count": 1262,
#         "follow_request_sent": null,
#         "followers_count": 7558,
#         "following": null,
#         "friends_count": 7569,
#         "geo_enabled": false,
#         "id": 1211014522435072000,
#         "id_str": "1211014522435072000",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 0,
#         "location": "I\u2019m the same here as IRL",
#         "name": "\ud83c\uddfa\ud83c\uddf8 MURCH \ud83c\uddfa\ud83c\uddf8",
#         "notifications": null,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": "",
#         "profile_background_image_url_https": "",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1211014522435072000/1587667212",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1348112382179074049/ozrdO7ik_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1348112382179074049/ozrdO7ik_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Mc_Murcher44",
#         "statuses_count": 21001,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false,
#         "withheld_in_countries": []
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 03 17:24:57 +0000 2021",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 1352565461058080769,
#                 "id_str": "1352565461058080769",
#                 "indices": [
#                     3,
#                     13
#                 ],
#                 "name": "Marco Alfonso \uea00",
#                 "screen_name": "BotXVersa"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 1433843468569247746,
#     "id_str": "1433843468569247746",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "tl",
#     "place": null,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Tue Aug 31 13:27:48 +0000 2021",
#         "display_text_range": [
#             0,
#             140
#         ],
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/1432696624359243776",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/Y7lmzcQqo4"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "extended_tweet": {
#             "display_text_range": [
#                 0,
#                 282
#             ],
#             "entities": {
#                 "hashtags": [],
#                 "media": [
#                     {
#                         "additional_media_info": {
#                             "monetizable": false
#                         },
#                         "display_url": "pic.twitter.com/9QJZAGyEka",
#                         "expanded_url": "https://twitter.com/BotXVersa/status/1432696624359243776/video/1",
#                         "id": 1432694817146867712,
#                         "id_str": "1432694817146867712",
#                         "indices": [
#                             283,
#                             306
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1432694817146867712/pu/img/-pTiH7zSKyzTCdzQ.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1432694817146867712/pu/img/-pTiH7zSKyzTCdzQ.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 720,
#                                 "resize": "fit",
#                                 "w": 1280
#                             },
#                             "medium": {
#                                 "h": 675,
#                                 "resize": "fit",
#                                 "w": 1200
#                             },
#                             "small": {
#                                 "h": 383,
#                                 "resize": "fit",
#                                 "w": 680
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "type": "video",
#                         "url": "https://t.co/9QJZAGyEka",
#                         "video_info": {
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ],
#                             "duration_millis": 140000,
#                             "variants": [
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1432694817146867712/pu/vid/640x360/uvjeXvNqTZBdcJqU.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1432694817146867712/pu/vid/480x270/808Hfa4gemYl9MRQ.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1432694817146867712/pu/vid/1280x720/2dPstf10hRVxY83L.mp4?tag=12"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/1432694817146867712/pu/pl/zdo65v3Gz7aVxK2F.m3u8?tag=12&container=fmp4"
#                                 }
#                             ]
#                         }
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": []
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "additional_media_info": {
#                             "monetizable": false
#                         },
#                         "display_url": "pic.twitter.com/9QJZAGyEka",
#                         "expanded_url": "https://twitter.com/BotXVersa/status/1432696624359243776/video/1",
#                         "id": 1432694817146867712,
#                         "id_str": "1432694817146867712",
#                         "indices": [
#                             283,
#                             306
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1432694817146867712/pu/img/-pTiH7zSKyzTCdzQ.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1432694817146867712/pu/img/-pTiH7zSKyzTCdzQ.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 720,
#                                 "resize": "fit",
#                                 "w": 1280
#                             },
#                             "medium": {
#                                 "h": 675,
#                                 "resize": "fit",
#                                 "w": 1200
#                             },
#                             "small": {
#                                 "h": 383,
#                                 "resize": "fit",
#                                 "w": 680
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "type": "video",
#                         "url": "https://t.co/9QJZAGyEka",
#                         "video_info": {
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ],
#                             "duration_millis": 140000,
#                             "variants": [
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1432694817146867712/pu/vid/640x360/uvjeXvNqTZBdcJqU.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1432694817146867712/pu/vid/480x270/808Hfa4gemYl9MRQ.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1432694817146867712/pu/vid/1280x720/2dPstf10hRVxY83L.mp4?tag=12"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/1432694817146867712/pu/pl/zdo65v3Gz7aVxK2F.m3u8?tag=12&container=fmp4"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             "full_text": "m\u0332a\u0332l\u0332i\u0332k\u0332 d\u0332e\u0332l\u0332g\u0332a\u0332t\u0332y\u0332 sa labor ng asawa sa hospital\u066b yung doctor ng asawa mo naman ang trip ka\u066b at tigang ka nanaman kaya sex nanaman ang ganap \ud83d\udca6\n\nPART 2/9\nRT &amp; LIKE for MORE\n\nSUBSCRIBE to TELEGRAM for 250php ONLY, OneTime Payment! Lifetime Access! All videos in One Channel https://t.co/9QJZAGyEka"
#         },
#         "favorite_count": 841,
#         "favorited": false,
#         "filter_level": "low",
#         "geo": null,
#         "id": 1432696624359243776,
#         "id_str": "1432696624359243776",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "tl",
#         "place": null,
#         "possibly_sensitive": true,
#         "quote_count": 1,
#         "reply_count": 0,
#         "retweet_count": 484,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "text": "m\u0332a\u0332l\u0332i\u0332k\u0332 d\u0332e\u0332l\u0332g\u0332a\u0332t\u0332y\u0332 sa labor ng asawa sa hospital\u066b yung doctor ng asawa mo naman ang trip ka\u066b at tigang ka na\u2026 https://t.co/Y7lmzcQqo4",
#         "truncated": true,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Fri Jan 22 10:35:19 +0000 2021",
#             "default_profile": true,
#             "default_profile_image": false,
#             "description": "Scorpio | 30's | 5'4 | SPAgoer | DogLover | Porn Addict | Selling Videos |",
#             "favourites_count": 2675,
#             "follow_request_sent": null,
#             "followers_count": 130265,
#             "following": null,
#             "friends_count": 361,
#             "geo_enabled": true,
#             "id": 1352565461058080769,
#             "id_str": "1352565461058080769",
#             "is_translator": false,
#             "lang": null,
#             "listed_count": 246,
#             "location": "Republic of the Philippines",
#             "name": "Marco Alfonso \uea00",
#             "notifications": null,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": "",
#             "profile_background_image_url_https": "",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1352565461058080769/1626120664",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1422968905295822853/J4jC3NeS_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1422968905295822853/J4jC3NeS_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BotXVersa",
#             "statuses_count": 3705,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": null,
#             "utc_offset": null,
#             "verified": false,
#             "withheld_in_countries": []
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "RT @BotXVersa: m\u0332a\u0332l\u0332i\u0332k\u0332 d\u0332e\u0332l\u0332g\u0332a\u0332t\u0332y\u0332 sa labor ng asawa sa hospital\u066b yung doctor ng asawa mo naman ang trip ka\u066b at tigang ka nanaman kay\u2026",
#     "timestamp_ms": "1630689897087",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sat Jun 22 09:23:20 +0000 2019",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Fuck Me!",
#         "favourites_count": 988,
#         "follow_request_sent": null,
#         "followers_count": 222,
#         "following": null,
#         "friends_count": 1501,
#         "geo_enabled": false,
#         "id": 1142362421354323968,
#         "id_str": "1142362421354323968",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 1,
#         "location": "Pasig",
#         "name": "Fuck You",
#         "notifications": null,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": "",
#         "profile_background_image_url_https": "",
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1164900148389900288/b_X6ZKNG_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1164900148389900288/b_X6ZKNG_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "hindutanLagi",
#         "statuses_count": 4955,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false,
#         "withheld_in_countries": []
#     }
# }
# done
